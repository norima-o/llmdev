# %%
# 名前と年齢を格納する変数
name = "小木曽 法勝"
age = 55

# 自己紹介の出力
print("はじめまして、", name, "と申します。")
print("年齢は", age, "歳です。来年は", age + 1, "歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、 小木曽 法勝 と申します。
# 年齢は 55 歳です。来年は 56 歳になります。
# よろしくお願いします。
