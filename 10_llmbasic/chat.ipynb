# %% [markdown]
# ## APIリクエストの準備

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# {'_request_id': 'req_115f56e99d284e74a01813fd66a5c142',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に活用するためのポイントはいくつかあります。以下に主なポイントを挙げます。\n\n1. **明確な目的設定**: まず、言語モデルを使用する目的を明確にします。例えば、質問応答、要約、文章生成、翻訳など、具体的な用途を意識することで、より効果的に活用できます。\n\n2. **プロンプト設計**: 入力するプロンプト（指示文や質問文）を工夫することで、出力の質が大きく変わります。具体的で明確な指示を与えることで、望む結果を得やすくなります。\n\n3. **文脈を考慮**: 言語モデルは前後の文脈を理解する能力があります。必要に応じて文脈を示す情報を追加することで、より適切な応答を引き出せます。\n\n4. **安全性と倫理**: 使用する際には、生成されるコンテンツの安全性や倫理的な側面を考慮することが重要です。特に、人種、性別、宗教などの敏感なテーマについては注意が必要です。\n\n5. **結果の評価**: 出力された情報は必ず検証し、信頼性や正確性を確認します。モデルが生成した内容は必ずしも正確でない場合があるため、自分自身の判断が重要です。\n\n6. **反復的な利用**: 最初の結果が満足できない場合、プロンプトを修正したり、再度質問を試みたりすることで、より良い出力を得ることができます。\n\n7. **用途に応じたカスタマイズ**: 特定のタスクに対してモデルをファインチューニングしたり、特定のデータセットで訓練し直したりすることで、より専門的な応答を得ることも可能です。\n\nこれらのポイントに留意することで、言語モデルをより効果的に活用できるでしょう。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))],
#  'created': 1771480927,
#  'id': 'chatcmpl-DArOxEprK12DNnOFUhBVKPahzawmQ',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_373a14eb6f',
#  'usage': CompletionUsage(completion_tokens=478, prompt_tokens=18, total_tokens=496, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
# 言語モデルを効果的に活用するためのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確な目的設定**: まず、言語モデルを使用する目的を明確にします。例えば、質問応答、要約、文章生成、翻訳など、具体的な用途を意識することで、より効果的に活用できます。
#
# 2. **プロンプト設計**: 入力するプロンプト（指示文や質問文）を工夫することで、出力の質が大きく変わります。具体的で明確な指示を与えることで、望む結果を得やすくなります。
#
# 3. **文脈を考慮**: 言語モデルは前後の文脈を理解する能力があります。必要に応じて文脈を示す情報を追加することで、より適切な応答を引き出せます。
#
# 4. **安全性と倫理**: 使用する際には、生成されるコンテンツの安全性や倫理的な側面を考慮することが重要です。特に、人種、性別、宗教などの敏感なテーマについては注意が必要です。
#
# 5. **結果の評価**: 出力された情報は必ず検証し、信頼性や正確性を確認します。モデルが生成した内容は必ずしも正確でない場合があるため、自分自身の判断が重要です。
#
# 6. **反復的な利用**: 最初の結果が満足できない場合、プロンプトを修正したり、再度質問を試みたりすることで、より良い出力を得ることができます。
#
# 7. **用途に応じたカスタマイズ**: 特定のタスクに対してモデルをファインチューニングしたり、特定のデータセットで訓練し直したりすることで、より専門的な応答を得ることも可能です。
#
# これらのポイントに留意することで、言語モデルをより効果的に活用できるでしょう。

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"


# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略を考える際には、以下のステップを考慮することが重要です。
#
# ### 1. 市場調査
# - **ターゲット市場の特定**: 顧客セグメントを明確にし、特定のニーズや好みを理解します。
# - **競合分析**: 競合他社の製品やマーケティング戦略を分析し、差別化ポイントを確認します。
#
# ### 2. 製品のポジショニング
# - **ユニークセリングプロポジション (USP)**: 製品の特長や利点、他製品と差別化されるポイントを明確にします。
# - **ブランドメッセージの策定**: 製品が提供する価値を伝えるためのメッセージを作成します。
#
# ### 3. マーケティングキャンペーンの計画
# - **ローンチ戦略**: いつ、どのように製品を発表するかを計画します。プレローンチ活動を考慮することで、期待感を高めることができます。
# - **マルチチャネルアプローチ**: ソーシャルメディア、メールマーケティング、ウェブサイト、広告（オンライン・オフライン）のいずれも利用することで、広範囲にリーチします。
#
# ### 4. コンテンツ制作
# - **教育的コンテンツの作成**: 製品の使い方や利点についてのブログ記事、動画、ウェビナーを作成します。
# - **ソーシャルメディアアクティビティの強化**: 製品の発売に関連するキャンペーンやコンテストを通じて、ユーザーエンゲージメントを促進します。
#
# ### 5. テストマーケティング
# - **パイロットプログラム**: 限定的な市場で製品を試験的に発売し、フィードバックを収集します。
# - **ユーザーエクスペリエンスの改善**: 収集したデータを基に、製品やマーケティングメッセージを調整します。
#
# ### 6. 発売後のフォローアップ
# - **顧客フィードバックの収集**: 購入後の顧客からのフィードバックを収集し、進行中の改善を行います。
# - **リテンション施策**: ロイヤリティプログラムやアップセル、クロスセルを通じて、既存顧客との関係を強化します。
#
# ### 7. 成果の評価
# - **KPIsの設定とモニタリング**: ROAS（Return on Advertising Spend）、CTR（Click Through Rate）、顧客獲得コスト（CAC）などの指標を設定し、成果を測定します。
# - **レポーティングと改善策**: 定期的に結果を分析し、次のキャンペーンに向けた戦略を修正します。
#
# これらのステップに従って、新製品の発売を成功させるための戦略を練りましょう。成功するためには、顧客のニーズを理解し、柔軟に対応することが不可欠です。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=0.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然の美しさが融合した魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を体験できる素晴らしい機
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかご紹介します。
#
# 1. **文化と伝統**: 日本は古くからの伝統と現代文化が共存しています。茶道、花道、武道などの伝統芸能や、祭りや神社仏閣などの文化遺産が豊富です。
#
# 2. **美しい自然**: 日本は四季がはっきり
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかご紹介します。
#
# 1. **文化と伝統**: 日本は古くからの伝統と現代文化が共存しています。茶道、花道、武道などの伝統芸能や、祭りや神社仏閣などの文化遺産が豊富です。
#
# 2. **美しい自然**: 日本は四季がはっきり

# %%
import tiktoken
from tiktoken.core import Encoding

# 使うモデル名を定義
MODEL_NAME = "gpt-4o-mini"

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
import sys
# !{sys.executable} -m pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\2500715\appdata\local\programs\python\python312\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\2500715\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\2500715\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\2500715\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\2500715\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken) (2026.1.4)
# Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl (878 kB)
#    ---------------------------------------- 0.0/878.7 kB ? eta -:--:--
#    ---------------------------------------- 878.7/878.7 kB 7.9 MB/s eta 0:00:00
# Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl (277 kB)
# Installing collected packages: regex, tiktoken
# Successfully installed regex-2026.1.15 tiktoken-0.12.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、お久しぶりですね！最近どうしてましたか？
# --------------------
# B:こんにちは！Aさん！元気ですか？
# --------------------
# B:こんにちは！Aさん、元気でしたか？

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確な目的設定**: 言語モデルを利用する目的を明確にすることが重要です。例えば、文章生成、要約、翻訳、質問応答など、具体的な用途を定めることで、適切な入力や設定を行いやすくなります。
#
# 2. **入力の工夫**: 言語モデルは入力によって出力が大きく変わります。質問やリクエストを具体的かつ明確にすることで、期待する結果を得やすくなります。また、必要に応じて文脈情報を追加することも効果的です。
#
# 3. **出力の評価**: モデルから得られた出力は、必ずしも正確とは限りません。生成された内容をチェックし、必要に応じて修正や改善を加えることが大切です。
#
# 4. **倫理的配慮**: 言語モデルが生成するコンテンツに対する倫理的な配慮も重要です。誤情報や偏見を助長する可能性があるため、出力には注意を払う必要があります。
#
# 5. **モデルのバージョンや性能**: 使用する言語モデルによって性能や特性が異なります。最新のモデルを使用することで、より高品質な出力が得られることが多いですが、それに伴うコストや技術的な要件も考慮する必要があります。
#
# 6. **カスタマイズとフィンチューニング**: 特定のタスクに対してモデルをさらに訓練する（フィンチューニング）ことで、より専門的な結果を得ることが可能です。これにより、特定の業界や分野に特化した応答を生成することができます。
#
# 7. **ユーザーとのインタラクション**: 利用者が言語モデルとどのようにインタラクションするかも重要です。使いやすさやインターフェースの設計に工夫を凝らすことで、モデルの効果を最大限に引き出すことができます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができるでしょう。
